# %%
import pandas as pd

# %%
theFile="../datasets/oregon_2017.csv"

# %%
firstTryDf=pd.read_csv(theFile, index_col=None)

# %%
firstTryDf.head()
# Out:
#         GEO.id GEO.id2 GEO.display-label         HD01_VD01  \
# 0           Id     Id2         Geography  Estimate; Total:
# 1  0400000US41      41            Oregon           4102901
#
#                  HD02_VD01        HD01_VD02               HD02_VD02  \
# 0  Margin of Error; Total:  Estimate; Male:  Margin of Error; Male:
# 1                     1020          2024505                    4244
#
#                           HD01_VD03                                HD02_VD03  \
# 0  Estimate; Male: - Under 6 years:  Margin of Error; Male: - Under 6 years:
# 1                            141548                                     2920
#
#                                            HD01_VD04  \
# 0  Estimate; Male: - Under 6 years: - With health...
# 1                                             136694
#
#                          ...                          \
# 0                        ...
# 1                        ...
#
#                                            HD01_VD53  \
# ...

# %%
firstTryTDf=firstTry.T

# %%
or17Df=firstTryTDf.reset_index(drop=True)

# %%
or17Df.head()
# Out:
#                          0            1
# 0                       Id  0400000US41
# 1                      Id2           41
# 2                Geography       Oregon
# 3         Estimate; Total:      4102901
# 4  Margin of Error; Total:         1020

# %%
or17Df=or17Df.rename(columns={0:'name',1:'value'})

# %%
noHealthInsDf=or17Df[(or17Df['name'].str.contains('Estimate')) & 
       (or17Df['name'].str.contains('No health insurance coverage'))]

# %%
#noHealthInsDf.loc['valueNum']=pd.to_numeric(noHealthInsDf.loc['value'])
noHealthInsDf['valueNum']=pd.to_numeric(noHealthInsDf['value'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
noHealthInsDf.head()
# Out:
#                                                  name  value  valueNum
# 11  Estimate; Male: - Under 6 years: - No health i...   4854    4854.0
# 17  Estimate; Male: - 6 to 18 years: - No health i...  13223   13223.0
# 23  Estimate; Male: - 19 to 25 years: - No health ...  25503   25503.0
# 29  Estimate; Male: - 26 to 34 years: - No health ...  38938   38938.0
# 35  Estimate; Male: - 35 to 44 years: - No health ...  35540   35540.0

# %%
noInsSum=noHealthInsDf['valueNum'].sum()
noInsSum
# Out:
# 280816.0

# %%
estTotalDf=or17Df[or17Df['name'].str.contains('Estimate; Total:')]
estTotalNum =pd.to_numeric(estTotalDf['value'])

# %%
noInsRateOregon_17=noInsSum/estTotalNum
noInsRateOregon_17
# Out:
# 3    0.068443
# Name: value, dtype: float64

# %%
cuongFile='../datasets/Cuong_etlExcelFiles/Ohio_2017.csv'noInsRate17Or
cfDf=pd.read_csv(cuongFile)
cfDf.head()
# Out:
#         GEO.id GEO.id2 GEO.display-label         HD01_VD01  \
# 0           Id     Id2         Geography  Estimate; Total:
# 1  0400000US39      39              Ohio          11485078
#
#                  HD02_VD01        HD01_VD02               HD02_VD02  \
# 0  Margin of Error; Total:  Estimate; Male:  Margin of Error; Male:
# 1                     1447          5600497                    6227
#
#                           HD01_VD03                                HD02_VD03  \
# 0  Estimate; Male: - Under 6 years:  Margin of Error; Male: - Under 6 years:
# 1                            419105                                     5047
#
#                                            HD01_VD04  \
# 0  Estimate; Male: - Under 6 years: - With health...
# 1                                             402535
#
#                          ...                          \
# 0                        ...
# 1                        ...
#
#                                            HD01_VD53  \
# ...

# %%
cfDf.T.head()
# Out:
#                                          0            1
# GEO.id                                  Id  0400000US39
# GEO.id2                                Id2           39
# GEO.display-label                Geography         Ohio
# HD01_VD01                 Estimate; Total:     11485078
# HD02_VD01          Margin of Error; Total:         1447
