# %%
import pandas as pd

# %%
theFile="../datasets/oregon_2017.csv"

# %%
firstTryDf=pd.read_csv(theFile, index_col=None)

# %%
firstTryDf.head()
# Out:
#         GEO.id GEO.id2 GEO.display-label         HD01_VD01  \
# 0           Id     Id2         Geography  Estimate; Total:
# 1  0400000US41      41            Oregon           4102901
#
#                  HD02_VD01        HD01_VD02               HD02_VD02  \
# 0  Margin of Error; Total:  Estimate; Male:  Margin of Error; Male:
# 1                     1020          2024505                    4244
#
#                           HD01_VD03                                HD02_VD03  \
# 0  Estimate; Male: - Under 6 years:  Margin of Error; Male: - Under 6 years:
# 1                            141548                                     2920
#
#                                            HD01_VD04  \
# 0  Estimate; Male: - Under 6 years: - With health...
# 1                                             136694
#
#                          ...                          \
# 0                        ...
# 1                        ...
#
#                                            HD01_VD53  \
# ...

# %%
firstTryTDf=firstTry.T

# %%
or17Df=firstTryTDf.reset_index(drop=True)

# %%
or17Df.head()
# Out:
#                          0            1
# 0                       Id  0400000US41
# 1                      Id2           41
# 2                Geography       Oregon
# 3         Estimate; Total:      4102901
# 4  Margin of Error; Total:         1020

# %%
or17Df=or17Df.rename(columns={0:'name',1:'value'})

# %%
or17Df[or17Df['name'].str.contains('Estimate')]
# Out:
#                                                   name    value
# 3                                     Estimate; Total:  4102901
# 5                                      Estimate; Male:  2024505
# 7                     Estimate; Male: - Under 6 years:   141548
# 9    Estimate; Male: - Under 6 years: - With health...   136694
# 11   Estimate; Male: - Under 6 years: - No health i...     4854
# 13                    Estimate; Male: - 6 to 18 years:   335077
# 15   Estimate; Male: - 6 to 18 years: - With health...   321854
# 17   Estimate; Male: - 6 to 18 years: - No health i...    13223
# 19                   Estimate; Male: - 19 to 25 years:   182185
# 21   Estimate; Male: - 19 to 25 years: - With healt...   156682
# 23   Estimate; Male: - 19 to 25 years: - No health ...    25503
# 25                   Estimate; Male: - 26 to 34 years:   258265
# 27   Estimate; Male: - 26 to 34 years: - With healt...   219327
# 29   Estimate; Male: - 26 to 34 years: - No health ...    38938
# ...

# %%
cuongFile='../Cuong_etlExcelFiles/Ohio_2017.
